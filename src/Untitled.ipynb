# %%
import xarray as xr

# %%
xdf = xr.open_dataset('../data/processed/augment_10_5/train_filter_vi_fill_smooth.nc')
xdf = xdf.set_coords(['Latitude', 'Longitude', 'District', 'Date of Harvest', 'Rice Crop Intensity(D=Double, T=Triple)', 'Field size (ha)', 'Rice Yield (kg/ha)'])
xdf = xdf.drop(['time', 'Season(SA = Summer Autumn, WS = Winter Spring)'])

# %%
df = xdf.to_dataframe().reset_index()

# %%
df.drop(columns='ts_id')
# Out:
#         state_dev   District Date of Harvest  \
# 0              23   Chau_Phu      15-07-2022
# 1              22   Chau_Phu      15-07-2022
# 2              21   Chau_Phu      15-07-2022
# 3              20   Chau_Phu      15-07-2022
# 4              19   Chau_Phu      15-07-2022
# ...           ...        ...             ...
# 133675          4  Thoai_Son      13-04-2022
# 133676          3  Thoai_Son      13-04-2022
# 133677          2  Thoai_Son      13-04-2022
# 133678          1  Thoai_Son      13-04-2022
# 133679          0  Thoai_Son      13-04-2022
#
#        Rice Crop Intensity(D=Double, T=Triple)      ndvi      savi       evi  \
# 0                                            T  0.188983  1.094483  1.688525
# 1                                            T  0.272829  1.136403  0.425410
# 2                                            T  0.344520  1.172246  2.188946
# 3                                            T  0.406485  1.203227  5.030591
# ...
